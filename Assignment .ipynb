# %%
##Assignment

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = sns.load_dataset("titanic")

# Set the style
sns.set_style("whitegrid")

# Bar Chart: Passenger count by class
plt.figure(figsize=(6, 4))
sns.countplot(data=titanic, x="class", palette="viridis")
plt.title("Passenger Count by Class")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# Pie Chart: Proportion of passengers by gender
gender_counts = titanic['sex'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=["#ff9999", "#66b3ff"])
plt.title("Proportion of Passengers by Gender")
plt.show()

# Histogram: Distribution of passenger ages
plt.figure(figsize=(6, 4))
sns.histplot(titanic['age'].dropna(), bins=20, kde=True, color='blue')
plt.title("Distribution of Passenger Ages")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
# Creating a set with the group name "Lionbreeze" and members
lionbreeze_members = {"Ben", "George", "Liston", "Mburu", "Wachira"}

# Print the set
print("Group Lionbreeze Members:", lionbreeze_members)
# Out:
# Group Lionbreeze Members: {'Liston', 'Mburu', 'George', 'Wachira', 'Ben'}

# %%
# Creating a dictionary with names and ages
lionbreeze_dict = {
    "Ben": 25,
    "George": 13,
    "Liston": 27,
    "Mburu": 22,
    "Wachira": 29
}

# Updating the dictionary with gender information
lionbreeze_dict.update({
    "Ben": {"age": 25, "gender": "Male"},
    "George": {"age": 13, "gender": "Male"},
    "Liston": {"age": 27, "gender": "Male"},
    "Mburu": {"age": 22, "gender": "Male"},
    "Wachira": {"age": 29, "gender": "Female"}
})

# Printing the updated dictionary
print("Updated Lionbreeze Dictionary:")
for name, details in lionbreeze_dict.items():
    print(name, "=>", details)
# Out:
# Updated Lionbreeze Dictionary:
# Ben => {'age': 25, 'gender': 'Male'}
# George => {'age': 13, 'gender': 'Male'}
# Liston => {'age': 27, 'gender': 'Male'}
# Mburu => {'age': 22, 'gender': 'Male'}
# Wachira => {'age': 29, 'gender': 'Female'}
